# %%
# %matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from pathlib import Path
from pyumls.umls_reader import read_umls
import pyumls.umls as umls
from collections import defaultdict, Counter
import itertools
# Out:
# Using matplotlib backend: TkAgg

# %%
#https://www.ncbi.nlm.nih.gov/books/NBK9685/
umls_conso = Path(r'/shared/hltdir1/disk1/home/max/data/ontologies/umls_2019/2019AA-full/2019AA/META/MRCONSO.RRF')
umls_def = Path(r'/shared/hltdir1/disk1/home/max/data/ontologies/umls_2019/2019AA-full/2019AA/META/MRDEF.RRF')
umls_rels = Path(r'/shared/hltdir1/disk1/home/max/data/ontologies/umls_2019/2019AA-full/2019AA/META/MRREL.RRF')
umls_hier = Path(r'/shared/hltdir1/disk1/home/max/data/ontologies/umls_2019/2019AA-full/2019AA/META/MRHIER.RRF')

# %%
def umls_rel_filter(x):
  # remove recursive relations
  if x.cui2 == x.cui1:
    return False
  # ignore siblings, CHD is enough to infer
  if x.rel == 'SIB':
    return False
  # ignore PAR, CHD is reflexive
  if x.rel == 'PAR':
    return False
  # ignore RO with no relA, not descriptive 
  if x.rel == 'RO' and x.rela == '':
    return False
  # reflexive with AQ
  if x.rel == 'QB':
    return False
  # too vague
  if x.rel == 'RB':
    return False
  return True

# %%
rel_iter = read_umls(
  umls_rels, 
  umls.UmlsRelation, 
  umls_filter=umls_rel_filter
)

rela_counter = Counter()
total_count = 0
for rel in rel_iter:
  rela_counter[(rel.rel, rel.rela)] += 1
  total_count += 1

print(f'{total_count} rels match filter.')
# Out:
# 20071511 rels match filter.

# %%
min_count = 100
kept_rel_count = 0
skipped_rel_count = 0

kept_rels = []
skipped_rels = []
for (rel, rela), rela_count in sorted(rela_counter.items(), key=lambda x: -x[1]):
  if rela_count < min_count:
    skipped_rels.append((rel, rela, rela_count))
    skipped_rel_count += rela_count
  else:
    kept_rels.append((rel, rela, rela_count))
    print(f'{rel}, {rela}, {rela_count}')
    kept_rel_count += rela_count
# Out:
# CHD, , 2125393
# CHD, isa, 1383066
# RO, has_inactive_ingredient, 1253624
# RO, inactive_ingredient_of, 1253624
# AQ, , 602217
# RO, has_finding_site, 355131
# RO, finding_site_of, 355131
# RN, mapped_to, 354410
# RO, has_active_ingredient, 342188
# RO, active_ingredient_of, 342188
# RO, method_of, 337561
# RO, has_method, 337561
# RN, , 321690
# RN, isa, 321396
# RQ, classifies, 316858
# RQ, classified_as, 316858
# RO, has_active_moiety, 284521
# RO, active_moiety_of, 284521
# RO, associated_morphology_of, 253171
# RO, has_associated_morphology, 253171
# RO, has_component, 249916
# RO, component_of, 249916
# RO, has_ingredient, 238135
# RO, ingredient_of, 238135
# RO, subset_includes_concept, 199280
# RO, concept_in_subset, 199280
# RO, dose_form_of, 133035
# RO, has_dose_form, 133035
# RO, has_procedure_site, 129560
# RO, procedure_site_of, 129560
# RO, has_system, 127876
# RO, system_of, 127876
# RO, has_manifestation, 113166
# RO, manifestation_of, 113166
# RO, constitutes, 110875
# RO, consists_of, 110875
# RN, tradename_of, 109579
# RO, has_class, 98438
# RO, class_of, 98438
# RO, has_fragments_for_synonyms, 95071
# RO, fragments_for_synonyms_of, 95071
# RO, has_time_aspect, 88953
# RO, time_aspect_of, 88953
# RO, scale_of, 85824
# RO, has_scale, 85824
# RO, has_property, 85545
# RO, property_of, 85545
# RO, has_causative_agent, 84622
# RO, causative_agent_of, 84622
# RN, part_of, 84035
# RO, has_direct_procedure_site, 82208
# RO, direct_procedure_site_of, 82208
# RO, may_be_treated_by, 81544
# RO, may_treat, 81544
# RO, is_interpreted_by, 80351
# RO, interprets, 80351
# RO, has_answer, 79378
# RO, answer_to, 79378
# RO, measures, 78947
# RO, measured_by, 78947
# RO, analyzes, 72041
# RO, analyzed_by, 72041
# RO, possibly_equivalent_to, 65964
# RO, mapped_to, 63108
# RO, mapped_from, 63108
# RQ, , 59292
# RO, physiologic_effect_of, 55461
# RO, has_physiologic_effect, 55461
# RO, has_contraindicated_drug, 51755
# RO, contraindicated_with_disease, 51755
# RO, pathological_process_of, 51006
# RO, has_pathological_process, 51006
# RO, is_abnormal_cell_of_disease, 46877
# RO, disease_has_abnormal_cell, 46877
# RO, has_product_component, 41393
# RO, product_component_of, 41393
# RN, member_of, 40441
# RO, mechanism_of_action_of, 40257
# RO, has_mechanism_of_action, 40257
# RO, has_occurrence, 38683
# RO, occurs_in, 38683
# RO, doseformgroup_of, 36868
# RO, has_doseformgroup, 36868
# RO, gene_plays_role_in_process, 36159
# RO, process_involves_gene, 36159
# RO, is_associated_anatomic_site_of, 35182
# RO, disease_has_associated_anatomic_site, 35182
# RO, mapping_qualifier_of, 34941
# RO, has_mapping_qualifier, 34941
# RO, disease_has_finding, 34569
# RO, is_finding_of_disease, 34569
# RO, has_suffix, 33039
# RO, suffix_of, 33039
# RO, has_phenotype, 29871
# RO, phenotype_of, 29871
# RO, has_direct_morphology, 29450
# RO, direct_morphology_of, 29450
# RQ, allelic_variant_of, 28045
# RQ, has_allelic_variant, 28045
# RO, has_regional_part, 27627
# RO, regional_part_of, 27627
# RO, has_indirect_procedure_site, 26964
# RO, indirect_procedure_site_of, 26964
# RO, intent_of, 25807
# RO, has_intent, 25807
# RO, disease_has_primary_anatomic_site, 22837
# RO, is_primary_anatomic_site_of_disease, 22837
# RO, has_direct_substance, 22706
# RO, direct_substance_of, 22706
# RO, interpretation_of, 22664
# RO, has_interpretation, 22664
# RO, disease_excludes_finding, 22525
# RO, is_not_finding_of_disease, 22525
# RO, constitutional_part_of, 21420
# RO, has_constitutional_part, 21420
# RO, has_multipart, 21044
# RO, multipart_of, 21044
# RO, gene_product_plays_role_in_biological_process, 20630
# RO, biological_process_involves_gene_product, 20630
# CHD, part_of, 19395
# RO, has_challenge, 19300
# RO, challenge_of, 19300
# RO, is_normal_tissue_origin_of_disease, 18749
# RO, disease_has_normal_tissue_origin, 18749
# RO, has_supersystem, 18469
# RO, supersystem_of, 18469
# CHD, has_parent, 18113
# RO, is_normal_cell_origin_of_disease, 18084
# RO, disease_has_normal_cell_origin, 18084
# RO, gene_encodes_gene_product, 17928
# RO, gene_product_encoded_by_gene, 17928
# RO, direct_device_of, 17608
# RO, has_direct_device, 17608
# RO, moved_from, 17336
# RO, moved_to, 17336
# RO, is_not_abnormal_cell_of_disease, 17037
# RO, disease_excludes_abnormal_cell, 17037
# RO, temporal_context_of, 16708
# RO, has_temporal_context, 16708
# RO, subject_relationship_context_of, 16447
# RO, has_subject_relationship_context, 16447
# RO, disease_may_have_finding, 16164
# RO, may_be_finding_of_disease, 16164
# RN, was_a, 15587
# RO, entire_anatomy_structure_of, 14162
# RO, has_entire_anatomy_structure, 14162
# RO, has_gene_product_element, 13414
# RO, gene_product_is_element_in_pathway, 13414
# RO, gene_is_element_in_pathway, 13305
# RO, pathway_has_gene_element, 13305
# RO, may_be_prevented_by, 12362
# RO, may_prevent, 12362
# RO, chemical_structure_of, 12320
# RO, has_chemical_structure, 12320
# RO, associated_finding_of, 12137
# RO, has_associated_finding, 12137
# RO, branch_of, 12093
# RO, has_branch, 12093
# RO, associated_with, 11736
# RO, has_count_of_base_of_active_ingredient, 11713
# RO, count_of_base_of_active_ingredient_of, 11713
# RO, has_ingredients, 11649
# RO, ingredients_of, 11649
# RO, chemotherapy_regimen_has_component, 11381
# RO, is_component_of_chemotherapy_regimen, 11381
# RO, device_used_by, 10983
# RO, uses_device, 10983
# RO, finding_context_of, 10958
# RO, has_finding_context, 10958
# RO, definitional_manifestation_of, 10882
# RO, has_definitional_manifestation, 10882
# RO, has_part, 10610
# RO, part_of, 10610
# RO, may_be_cytogenetic_abnormality_of_disease, 10583
# RO, disease_may_have_cytogenetic_abnormality, 10583
# SY, same_as, 10512
# RQ, mapped_to, 10191
# RQ, mapped_from, 10191
# RO, access_of, 9495
# RO, has_access, 9495
# RO, evaluation_of, 9398
# RO, has_evaluation, 9398
# RO, has_physical_part_of_anatomic_structure, 9336
# RO, anatomic_structure_is_physical_part_of, 9336
# RO, disposition_of, 9176
# RO, has_disposition, 9176
# RO, finding_method_of, 9110
# RO, has_finding_method, 9110
# RO, laterality_of, 8804
# RO, has_laterality, 8804
# RO, due_to, 8784
# RO, cause_of, 8784
# RO, may_be_molecular_abnormality_of_disease, 8720
# RO, disease_may_have_molecular_abnormality, 8720
# RQ, used_for, 8213
# RQ, use, 8213
# RO, uses, 7663
# RO, used_by, 7663
# RO, occurs_after, 7206
# RO, occurs_before, 7206
# RO, regulates, 7180
# RO, regulated_by, 7180
# RQ, clinically_similar, 6916
# RO, therapeutic_class_of, 6834
# RO, has_therapeutic_class, 6834
# RO, uses_substance, 6759
# RO, substance_used_by, 6759
# RN, has_precise_ingredient, 6671
# RO, has_basis_of_strength_substance, 6554
# RO, basis_of_strength_substance_of, 6554
# RO, has_focus, 6493
# RO, focus_of, 6493
# RO, has_measured_component, 6301
# RO, measured_component_of, 6301
# RO, has_imaged_location, 6270
# RO, is_imaged_location_for, 6270
# RO, negatively_regulates, 6260
# RO, negatively_regulated_by, 6260
# RO, positively_regulates, 6248
# RO, positively_regulated_by, 6248
# RO, is_stage_of_disease, 6084
# RO, disease_is_stage, 6084
# RO, has_precise_active_ingredient, 5992
# RO, precise_active_ingredient_of, 5992
# RO, has_modality_type, 5967
# RO, is_modality_type_for, 5967
# RO, procedure_context_of, 5765
# RO, has_procedure_context, 5765
# RO, has_associated_procedure, 5748
# RO, associated_procedure_of, 5748
# RO, inheritance_type_of, 5652
# RO, has_inheritance_type, 5652
# RO, has_presentation_strength_numerator_value, 5431
# RO, presentation_strength_numerator_value_of, 5431
# RO, has_divisor, 5405
# RO, divisor_of, 5405
# RO, has_imaging_focus, 5385
# RO, is_imaging_focus_of, 5385
# CHD, branch_of, 5327
# RN, quantified_form_of, 5307
# RO, is_not_normal_cell_origin_of_disease, 5272
# RO, disease_excludes_normal_cell_origin, 5272
# RO, nichd_parent_of, 5234
# RO, has_nichd_parent, 5234
# RO, presentation_strength_numerator_unit_of, 4998
# RO, has_presentation_strength_numerator_unit, 4998
# RO, is_associated_anatomy_of_gene_product, 4966
# CHD, member_of, 4966
# RO, gene_product_has_associated_anatomy, 4966
# RO, gene_mapped_to_disease, 4859
# RO, disease_mapped_to_gene, 4859
# SY, has_tradename, 4843
# SY, tradename_of, 4843
# RO, is_structural_domain_or_motif_of_gene_product, 4810
# RO, gene_product_has_structural_domain_or_motif, 4810
# RO, course_of, 4808
# RO, has_course, 4808
# RO, has_presentation_strength_denominator_value, 4763
# RO, presentation_strength_denominator_value_of, 4763
# RO, presentation_strength_denominator_unit_of, 4763
# RO, has_presentation_strength_denominator_unit, 4763
# RO, related_to, 4720
# RO, clinical_course_of, 4719
# RO, has_clinical_course, 4719
# RO, is_biochemical_function_of_gene_product, 4571
# RO, gene_product_has_biochemical_function, 4571
# RO, member_of, 4495
# RO, has_member, 4495
# RO, has_precise_ingredient, 4183
# RO, precise_ingredient_of, 4183
# RO, unit_of_presentation_of, 4130
# RO, has_unit_of_presentation, 4130
# SY, , 4128
# RO, specimen_of, 4115
# RO, has_specimen, 4115
# RO, revision_status_of, 4088
# RO, has_revision_status, 4088
# RO, has_ctcae_5_parent, 4048
# RO, ctcae_5_parent_of, 4048
# RO, gene_in_chromosomal_location, 3813
# RO, is_chromosomal_location_of_gene, 3813
# RO, temporally_followed_by, 3778
# RO, temporally_follows, 3778
# RO, is_not_primary_anatomic_site_of_disease, 3729
# RO, disease_excludes_primary_anatomic_site, 3729
# RN, conceptual_part_of, 3590
# RO, related_part, 3584
# RO, has_lateral_anatomic_location, 3464
# RO, is_lateral_anatomic_location_of, 3464
# RO, has_lateral_location_presence, 3446
# RO, is_presence_of_lateral_location, 3446
# RO, gene_found_in_organism, 3417
# RO, organism_has_gene, 3417
# RO, access_instrument_of, 3410
# RO, has_access_instrument, 3410
# RO, structural_class_of, 3364
# RO, has_structural_class, 3364
# RO, has_specimen_source_topography, 3323
# RO, specimen_source_topography_of, 3323
# RO, has_aggregation_view, 3289
# RO, is_aggregation_view_of, 3289
# RO, access_device_used_by, 3228
# RO, uses_access_device, 3228
# RO, replaced_by, 3197
# RO, replaces, 3197
# RO, eo_anatomy_is_associated_with_eo_disease, 3128
# RO, eo_disease_has_associated_eo_anatomy, 3128
# RO, approach_of, 3123
# RO, has_approach, 3123
# RO, has_location, 2910
# RO, location_of, 2910
# RN, form_of, 2841
# RO, has_tributary, 2759
# RO, tributary_of, 2759
# RO, has_timing_of, 2665
# RO, is_timing_for, 2665
# RO, finding_informer_of, 2584
# RO, has_finding_informer, 2584
# RO, continuous_with, 2512
# RO, has_given_pharmaceutical_substance, 2392
# RO, is_given_pharmaceutical_substance_for, 2392
# RQ, see, 2373
# RQ, see_from, 2373
# RN, contains, 2331
# RO, has_contraindicating_class, 2235
# RO, contraindicating_class_of, 2235
# RO, molecular_abnormality_involves_gene, 2197
# RO, gene_involved_in_molecular_abnormality, 2197
# RO, gene_associated_with_disease, 2177
# RO, disease_has_associated_gene, 2177
# RO, genetic_biomarker_related_to, 2170
# RO, related_to_genetic_biomarker, 2170
# RO, included_in, 2160
# RO, includes, 2160
# RO, is_mechanism_of_action_of_chemical_or_drug, 2146
# RO, chemical_or_drug_has_mechanism_of_action, 2146
# RO, has_nerve_supply, 2133
# RO, nerve_supply_of, 2133
# RO, has_modification, 2121
# RO, is_modification_of, 2121
# RN, lab_number_of, 2006
# RO, priority_of, 1982
# RO, has_priority, 1982
# RO, has_specimen_procedure, 1954
# RO, specimen_procedure_of, 1954
# RO, continuous_proximally_with, 1948
# RO, continuous_distally_with, 1948
# RO, is_physiologic_effect_of_chemical_or_drug, 1947
# RO, chemical_or_drug_has_physiologic_effect, 1947
# RO, has_pharmaceutical_route, 1909
# RO, is_pharmaceutical_route_for, 1909
# RO, cdrh_parent_of, 1885
# RO, has_cdrh_parent, 1885
# RO, has_specimen_substance, 1879
# RO, specimen_substance_of, 1879
# RO, has_concentration_strength_denominator_value, 1859
# RO, has_concentration_strength_numerator_value, 1859
# RO, concentration_strength_denominator_value_of, 1859
# RO, concentration_strength_numerator_unit_of, 1859
# RO, concentration_strength_denominator_unit_of, 1859
# RO, concentration_strength_numerator_value_of, 1859
# RO, has_concentration_strength_numerator_unit, 1859
# RO, has_concentration_strength_denominator_unit, 1859
# RQ, consider, 1830
# RQ, consider_from, 1830
# RO, eo_disease_maps_to_human_disease, 1829
# RO, human_disease_maps_to_eo_disease, 1829
# RO, has_free_acid_or_base_form, 1824
# RO, has_salt_form, 1824
# RO, disease_may_have_associated_disease, 1821
# RO, may_be_associated_disease_of_disease, 1821
# RO, contraindicated_class_of, 1791
# RO, has_contraindicated_class, 1791
# RO, has_indirect_morphology, 1764
# RO, indirect_morphology_of, 1764
# RO, has_view_type, 1668
# RO, is_view_type_for, 1668
# CHD, tributary_of, 1659
# RO, gene_product_has_chemical_classification, 1654
# RO, is_chemical_classification_of_gene_product, 1654
# RO, wound_has_communication_with, 1590
# RO, has_communication_with_wound, 1590
# RO, gene_product_expressed_in_tissue, 1562
# RO, tissue_is_expression_site_of_gene_product, 1562
# RO, surgical_approach_of, 1498
# RO, has_surgical_approach, 1498
# RO, realization_of, 1471
# RO, has_realization, 1471
# RO, is_molecular_abnormality_of_disease, 1383
# RO, disease_has_molecular_abnormality, 1383
# RO, is_organism_source_of_gene_product, 1305
# RO, gene_product_has_organism_source, 1305
# RO, extent_of, 1305
# RO, has_extent, 1305
# RO, may_be_diagnosed_by, 1252
# RO, may_diagnose, 1252
# RO, is_grade_of_disease, 1245
# RO, disease_is_grade, 1245
# RO, gene_product_sequence_variation_encoded_by_gene_mutant, 1231
# RO, gene_mutant_encodes_gene_product_sequence_variation, 1231
# RO, is_not_normal_tissue_origin_of_disease, 1191
# RO, disease_excludes_normal_tissue_origin, 1191
# RO, exhibited_by, 1185
# RO, exhibits, 1185
# RO, may_be_abnormal_cell_of_disease, 1145
# RO, disease_may_have_abnormal_cell, 1145
# RO, gene_involved_in_pathogenesis_of_disease, 1100
# RO, pathogenesis_of_disease_involves_gene, 1100
# RO, has_modality_subtype, 1069
# RO, is_modality_subtype_for, 1069
# RO, is_action_guidance_for, 1021
# RO, has_action_guidance, 1021
# RO, has_procedure_device, 1015
# RO, procedure_device_of, 1015
# RO, has_presence_guidance, 999
# RO, is_presence_guidance_for, 999
# RO, is_physical_location_of_gene, 989
# RO, gene_has_physical_location, 989
# RO, onset_of, 988
# RO, has_onset, 988
# RO, induces, 966
# RO, induced_by, 966
# RO, disease_has_associated_disease, 963
# RO, is_associated_disease_of, 963
# RO, role_played_by, 939
# RO, plays_role, 939
# RQ, has_alias, 916
# RQ, alias_of, 916
# RO, contraindicating_mechanism_of_action_of, 895
# RO, has_contraindicating_mechanism_of_action, 895
# RO, pharmacokinetics_of, 890
# RO, has_pharmacokinetics, 890
# RO, contains, 882
# RO, contained_in, 882
# RO, bounds, 873
# RO, bounded_by, 873
# RO, has_procedure_morphology, 845
# RO, procedure_morphology_of, 845
# RO, product_monograph_title_of, 828
# RO, has_product_monograph_title, 828
# RO, efferent_to, 823
# RO, afferent_to, 823
# RO, receives_input_from, 811
# RO, sends_output_to, 811
# RO, target_anatomy_has_procedure, 791
# RO, procedure_has_target_anatomy, 791
# RO, lymphatic_drainage_of, 764
# RO, has_lymphatic_drainage, 764
# RO, segmental_supply_of, 705
# RO, has_segmental_supply, 705
# RO, has_associated_etiologic_finding, 698
# RO, associated_etiologic_finding_of, 698
# RO, articulates_with, 688
# RO, contraindicating_physiologic_effect_of, 666
# RO, has_contraindicating_physiologic_effect, 666
# RO, is_target, 661
# RO, has_target, 661
# RO, energy_used_by, 650
# RO, uses_energy, 650
# RO, enzyme_metabolizes_chemical_or_drug, 636
# RO, chemical_or_drug_is_metabolized_by_enzyme, 636
# RO, arterial_supply_of, 632
# RO, has_arterial_supply, 632
# RO, cytogenetic_abnormality_involves_chromosome, 590
# RO, chromosome_involved_in_cytogenetic_abnormality, 590
# RQ, replaced_by, 575
# RQ, replaces, 575
# RO, anterior_to, 545
# RO, posterior_to, 545
# RO, is_location_of_biological_process, 542
# RO, biological_process_has_associated_location, 542
# RO, severity_of, 529
# RO, has_severity, 529
# RO, is_not_molecular_abnormality_of_disease, 524
# RO, disease_excludes_molecular_abnormality, 524
# RO, chemical_or_drug_affects_cell_type_or_tissue, 523
# RO, cell_type_or_tissue_affected_by_chemical_or_drug, 523
# RO, gene_product_malfunction_associated_with_disease, 509
# RO, associated_with_malfunction_of_gene_product, 509
# RO, complex_has_physical_part, 505
# RO, gene_product_is_physical_part_of, 505
# RO, receives_attachment_from, 500
# RO, attaches_to, 500
# RO, direct_right_of, 487
# RO, direct_left_of, 487
# RO, process_includes_biological_process, 484
# RO, biological_process_is_part_of_process, 484
# RN, refers_to, 481
# RO, is_not_cytogenetic_abnormality_of_disease, 480
# RO, disease_excludes_cytogenetic_abnormality, 480
# RO, excised_anatomy_has_procedure, 476
# RO, procedure_has_excised_anatomy, 476
# RO, superior_to, 469
# RO, inferior_to, 469
# RO, metabolic_site_of, 441
# RO, site_of_metabolism, 441
# RO, is_exam_for, 431
# RO, has_exam, 431
# RO, has_contraindicated_mechanism_of_action, 422
# RO, contraindicated_mechanism_of_action_of, 422
# RO, gene_product_variant_of_gene_product, 415
# RO, gene_product_has_gene_product_variant, 415
# RO, scale_type_of, 398
# RO, has_scale_type, 398
# RO, has_specimen_source_identity, 397
# RO, specimen_source_identity_of, 397
# RN, mapped_from, 387
# RO, regimen_has_accepted_use_for_disease, 387
# RO, disease_has_accepted_treatment_with_regimen, 387
# RO, supported_concept_relationship_in, 383
# RO, has_supported_concept_relationship, 383
# RO, has_maneuver_type, 380
# RO, is_maneuver_type_for, 380
# RO, chemical_or_drug_affects_gene_product, 374
# RO, gene_product_affected_by_chemical_or_drug, 374
# RO, instrumentation_of, 368
# RO, has_instrumentation, 368
# RO, is_object_guidance_for, 354
# RO, has_object_guidance, 354
# SY, print_name_of, 344
# SY, has_print_name, 344
# RO, is_approach_guidance_for, 340
# RO, has_approach_guidance, 340
# RO, biomarker_type_includes_gene_product, 337
# RO, gene_product_is_biomarker_type, 337
# RO, dose_form_intended_site_of, 337
# RO, has_dose_form_intended_site, 337
# RO, has_quotient, 335
# RO, quotient_of, 335
# RO, route_of_administration_of, 333
# RO, has_route_of_administration, 333
# RO, part_anatomy_structure_of, 323
# RO, has_part_anatomy_structure, 323
# RO, is_location_of_anatomic_structure, 312
# RO, anatomic_structure_has_location, 312
# RO, dose_form_administration_method_of, 289
# RO, has_dose_form_administration_method, 289
# RO, disease_has_cytogenetic_abnormality, 285
# RO, dose_form_release_characteristic_of, 285
# RO, is_cytogenetic_abnormality_of_disease, 285
# RO, adjustment_of, 285
# RO, has_adjustment, 285
# RO, has_dose_form_release_characteristic, 285
# RO, subject_of_information_of, 283
# RO, has_subject_of_information, 283
# RO, eo_disease_has_property_or_attribute, 277
# RO, is_property_or_attribute_of_eo_disease, 277
# RO, derives, 274
# RO, derives_from, 274
# RO, has_basic_dose_form, 273
# RO, basic_dose_form_of, 273
# RO, has_specimen_source_morphology, 271
# RO, specimen_source_morphology_of, 271
# RO, has_contraindicated_physiologic_effect, 270
# RO, contraindicated_physiologic_effect_of, 270
# RO, supported_concept_property_in, 260
# RO, has_supported_concept_property, 260
# RO, gene_has_abnormality, 259
# RO, is_abnormality_of_gene, 259
# RO, dose_form_transformation_of, 254
# RO, has_dose_form_transformation, 254
# RO, related_object, 252
# RO, associated_genetic_condition, 243
# RO, associated_disease, 243
# RO, projects_from, 224
# RO, has_projection, 224
# RO, receives_projection, 223
# RO, projects_to, 223
# RO, origin_of, 221
# RO, has_origin, 221
# RO, procedure_has_partially_excised_anatomy, 208
# RO, partially_excised_anatomy_has_procedure, 208
# RO, disease_has_metastatic_anatomic_site, 206
# RO, is_metastatic_anatomic_site_of_disease, 206
# RO, has_time_modifier, 206
# RO, time_modifier_of, 206
# RO, lateral_to, 204
# RO, medial_to, 204
# RO, inc_parent_of, 201
# RO, has_inc_parent, 201
# RO, has_indirect_device, 200
# RO, indirect_device_of, 200
# RO, developmental_stage_of, 193
# RO, has_developmental_stage, 193
# RO, episodicity_of, 191
# RO, has_episodicity, 191
# RO, distal_to, 182
# RO, proximal_to, 182
# RO, insertion_of, 180
# RO, allele_has_abnormality, 180
# RO, has_insertion, 180
# RO, abnormality_associated_with_allele, 180
# RO, chromosome_mapped_to_disease, 179
# RO, disease_mapped_to_chromosome, 179
# RO, disease_may_have_normal_cell_origin, 175
# RO, may_be_normal_cell_origin_of_disease, 175
# RN, has_alternative, 168
# RO, property_type_of, 166
# RO, has_property_type, 166
# RO, has_recipient_category, 156
# RO, inheres_in, 156
# RO, has_inherent_attribute, 156
# RO, recipient_category_of, 156
# RO, has_count, 148
# RO, count_of, 148
# RO, surrounds, 140
# RO, surrounded_by, 140
# RO, connected_to, 140
# RO, venous_drainage_of, 132
# RO, state_of_matter_of, 132
# RO, has_venous_drainage, 132
# RO, has_state_of_matter, 132
# RO, process_initiates_biological_process, 129
# RO, biological_process_has_initiator_process, 129
# RO, allele_plays_altered_role_in_process, 128
# RO, process_altered_by_allele, 128
# RO, characterized_by, 127
# RO, characterizes, 127
# RN, version_of, 125
# RO, manufactures, 117
# RO, manufactured_by, 117
# RO, chemical_or_drug_initiates_biological_process, 113
# RO, biological_process_has_initiator_chemical_or_drug, 113
# RO, receives_drainage_from, 107
# RO, drains_into, 107
# RO, special_category_includes_neoplasm, 105
# RO, neoplasm_has_special_category, 105
# RO, chromosomal_location_of_allele, 104
# RO, allele_in_chromosomal_location, 104

# %%
print(f'Kept {len(kept_rels)} rel types with {kept_rel_count} rels.')
print(f'Skipped {len(skipped_rels)} rel types with {skipped_rel_count} rels.')
# Out:
# Kept 629 rel types with 20066621 rels.
# Skipped 175 rel types with 4890 rels.

# %%
removed_rels = []
exit_early = False
for (f_rel, f_rela, f_count), (s_rel, s_rela, s_count) in zip(kept_rels[:-1], kept_rels[1:]):
  if f_count == s_count:
    print(f'({f_rel}:{f_rela}) ?= ({s_rel}:{s_rela}) ({f_count})')
    need_choice = True
    if f_rela[:4] == 'has_' and s_rela[-3:] == '_of':
      print('Auto resolve to keep left (1)')
      removed_rels.append((s_rel, s_rela, s_count))
      need_choice = False
    elif f_rela[-3:] == '_of' and s_rela[:4] == 'has_':
      print('Auto resolve to keep right (2)')
      removed_rels.append((f_rel, f_rela, f_count))
      need_choice = False
    while need_choice:
      choice = input('Keep left (1), keep right (2), skip (3), exit (0):')
      if choice == '1':
        removed_rels.append((s_rel, s_rela, s_count))
        need_choice = False
      elif choice == '2':
        removed_rels.append((f_rel, f_rela, f_count))
        need_choice = False
      elif choice == '3':
        need_choice = False
      elif choice == '0':
        print('Exiting early.')
        need_choice = False
        exit_early = True
      else:
        print(f'Invalid option: {choice}')
  if exit_early:
    break
# Out:
# (RO:has_inactive_ingredient) ?= (RO:inactive_ingredient_of) (1253624)
# Auto resolve to keep left (1)
# (RO:has_finding_site) ?= (RO:finding_site_of) (355131)
# Auto resolve to keep left (1)
# (RO:has_active_ingredient) ?= (RO:active_ingredient_of) (342188)
# Auto resolve to keep left (1)
# (RO:method_of) ?= (RO:has_method) (337561)
# Auto resolve to keep right (2)
# (RQ:classifies) ?= (RQ:classified_as) (316858)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:has_active_moiety) ?= (RO:active_moiety_of) (284521)
# Auto resolve to keep left (1)
# (RO:associated_morphology_of) ?= (RO:has_associated_morphology) (253171)
# Auto resolve to keep right (2)
# (RO:has_component) ?= (RO:component_of) (249916)
# Auto resolve to keep left (1)
# (RO:has_ingredient) ?= (RO:ingredient_of) (238135)
# Auto resolve to keep left (1)
# (RO:subset_includes_concept) ?= (RO:concept_in_subset) (199280)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:dose_form_of) ?= (RO:has_dose_form) (133035)
# Auto resolve to keep right (2)
# (RO:has_procedure_site) ?= (RO:procedure_site_of) (129560)
# Auto resolve to keep left (1)
# (RO:has_system) ?= (RO:system_of) (127876)
# Auto resolve to keep left (1)
# (RO:has_manifestation) ?= (RO:manifestation_of) (113166)
# Auto resolve to keep left (1)
# (RO:constitutes) ?= (RO:consists_of) (110875)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:has_class) ?= (RO:class_of) (98438)
# Auto resolve to keep left (1)
# (RO:has_fragments_for_synonyms) ?= (RO:fragments_for_synonyms_of) (95071)
# Auto resolve to keep left (1)
# (RO:has_time_aspect) ?= (RO:time_aspect_of) (88953)
# Auto resolve to keep left (1)
# (RO:scale_of) ?= (RO:has_scale) (85824)
# Auto resolve to keep right (2)
# (RO:has_property) ?= (RO:property_of) (85545)
# Auto resolve to keep left (1)
# (RO:has_causative_agent) ?= (RO:causative_agent_of) (84622)
# Auto resolve to keep left (1)
# (RO:has_direct_procedure_site) ?= (RO:direct_procedure_site_of) (82208)
# Auto resolve to keep left (1)
# (RO:may_be_treated_by) ?= (RO:may_treat) (81544)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:is_interpreted_by) ?= (RO:interprets) (80351)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_answer) ?= (RO:answer_to) (79378)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:measures) ?= (RO:measured_by) (78947)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:analyzes) ?= (RO:analyzed_by) (72041)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:mapped_to) ?= (RO:mapped_from) (63108)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:physiologic_effect_of) ?= (RO:has_physiologic_effect) (55461)
# Auto resolve to keep right (2)
# (RO:has_contraindicated_drug) ?= (RO:contraindicated_with_disease) (51755)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:pathological_process_of) ?= (RO:has_pathological_process) (51006)
# Auto resolve to keep right (2)
# (RO:is_abnormal_cell_of_disease) ?= (RO:disease_has_abnormal_cell) (46877)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:has_product_component) ?= (RO:product_component_of) (41393)
# Auto resolve to keep left (1)
# (RO:mechanism_of_action_of) ?= (RO:has_mechanism_of_action) (40257)
# Auto resolve to keep right (2)
# (RO:has_occurrence) ?= (RO:occurs_in) (38683)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:doseformgroup_of) ?= (RO:has_doseformgroup) (36868)
# Auto resolve to keep right (2)
# (RO:gene_plays_role_in_process) ?= (RO:process_involves_gene) (36159)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:is_associated_anatomic_site_of) ?= (RO:disease_has_associated_anatomic_site) (35182)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:mapping_qualifier_of) ?= (RO:has_mapping_qualifier) (34941)
# Auto resolve to keep right (2)
# (RO:disease_has_finding) ?= (RO:is_finding_of_disease) (34569)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_suffix) ?= (RO:suffix_of) (33039)
# Auto resolve to keep left (1)
# (RO:has_phenotype) ?= (RO:phenotype_of) (29871)
# Auto resolve to keep left (1)
# (RO:has_direct_morphology) ?= (RO:direct_morphology_of) (29450)
# Auto resolve to keep left (1)
# (RQ:allelic_variant_of) ?= (RQ:has_allelic_variant) (28045)
# Auto resolve to keep right (2)
# (RO:has_regional_part) ?= (RO:regional_part_of) (27627)
# Auto resolve to keep left (1)
# (RO:has_indirect_procedure_site) ?= (RO:indirect_procedure_site_of) (26964)
# Auto resolve to keep left (1)
# (RO:intent_of) ?= (RO:has_intent) (25807)
# Auto resolve to keep right (2)
# (RO:disease_has_primary_anatomic_site) ?= (RO:is_primary_anatomic_site_of_disease) (22837)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:has_direct_substance) ?= (RO:direct_substance_of) (22706)
# Auto resolve to keep left (1)
# (RO:interpretation_of) ?= (RO:has_interpretation) (22664)
# Auto resolve to keep right (2)
# (RO:disease_excludes_finding) ?= (RO:is_not_finding_of_disease) (22525)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:constitutional_part_of) ?= (RO:has_constitutional_part) (21420)
# Auto resolve to keep right (2)
# (RO:has_multipart) ?= (RO:multipart_of) (21044)
# Auto resolve to keep left (1)
# (RO:gene_product_plays_role_in_biological_process) ?= (RO:biological_process_involves_gene_product) (20630)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_challenge) ?= (RO:challenge_of) (19300)
# Auto resolve to keep left (1)
# (RO:is_normal_tissue_origin_of_disease) ?= (RO:disease_has_normal_tissue_origin) (18749)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:has_supersystem) ?= (RO:supersystem_of) (18469)
# Auto resolve to keep left (1)
# (RO:is_normal_cell_origin_of_disease) ?= (RO:disease_has_normal_cell_origin) (18084)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:gene_encodes_gene_product) ?= (RO:gene_product_encoded_by_gene) (17928)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:direct_device_of) ?= (RO:has_direct_device) (17608)
# Auto resolve to keep right (2)
# (RO:moved_from) ?= (RO:moved_to) (17336)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:is_not_abnormal_cell_of_disease) ?= (RO:disease_excludes_abnormal_cell) (17037)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:temporal_context_of) ?= (RO:has_temporal_context) (16708)
# Auto resolve to keep right (2)
# (RO:subject_relationship_context_of) ?= (RO:has_subject_relationship_context) (16447)
# Auto resolve to keep right (2)
# (RO:disease_may_have_finding) ?= (RO:may_be_finding_of_disease) (16164)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:entire_anatomy_structure_of) ?= (RO:has_entire_anatomy_structure) (14162)
# Auto resolve to keep right (2)
# (RO:has_gene_product_element) ?= (RO:gene_product_is_element_in_pathway) (13414)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:gene_is_element_in_pathway) ?= (RO:pathway_has_gene_element) (13305)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:may_be_prevented_by) ?= (RO:may_prevent) (12362)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:chemical_structure_of) ?= (RO:has_chemical_structure) (12320)
# Auto resolve to keep right (2)
# (RO:associated_finding_of) ?= (RO:has_associated_finding) (12137)
# Auto resolve to keep right (2)
# (RO:branch_of) ?= (RO:has_branch) (12093)
# Auto resolve to keep right (2)
# (RO:has_count_of_base_of_active_ingredient) ?= (RO:count_of_base_of_active_ingredient_of) (11713)
# Auto resolve to keep left (1)
# (RO:has_ingredients) ?= (RO:ingredients_of) (11649)
# Auto resolve to keep left (1)
# (RO:chemotherapy_regimen_has_component) ?= (RO:is_component_of_chemotherapy_regimen) (11381)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:device_used_by) ?= (RO:uses_device) (10983)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:finding_context_of) ?= (RO:has_finding_context) (10958)
# Auto resolve to keep right (2)
# (RO:definitional_manifestation_of) ?= (RO:has_definitional_manifestation) (10882)
# Auto resolve to keep right (2)
# (RO:has_part) ?= (RO:part_of) (10610)
# Auto resolve to keep left (1)
# (RO:may_be_cytogenetic_abnormality_of_disease) ?= (RO:disease_may_have_cytogenetic_abnormality) (10583)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RQ:mapped_to) ?= (RQ:mapped_from) (10191)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:access_of) ?= (RO:has_access) (9495)
# Auto resolve to keep right (2)
# (RO:evaluation_of) ?= (RO:has_evaluation) (9398)
# Auto resolve to keep right (2)
# (RO:has_physical_part_of_anatomic_structure) ?= (RO:anatomic_structure_is_physical_part_of) (9336)
# Auto resolve to keep left (1)
# (RO:disposition_of) ?= (RO:has_disposition) (9176)
# Auto resolve to keep right (2)
# (RO:finding_method_of) ?= (RO:has_finding_method) (9110)
# Auto resolve to keep right (2)
# (RO:laterality_of) ?= (RO:has_laterality) (8804)
# Auto resolve to keep right (2)
# (RO:due_to) ?= (RO:cause_of) (8784)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:may_be_molecular_abnormality_of_disease) ?= (RO:disease_may_have_molecular_abnormality) (8720)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RQ:used_for) ?= (RQ:use) (8213)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:uses) ?= (RO:used_by) (7663)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:occurs_after) ?= (RO:occurs_before) (7206)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:regulates) ?= (RO:regulated_by) (7180)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:therapeutic_class_of) ?= (RO:has_therapeutic_class) (6834)
# Auto resolve to keep right (2)
# (RO:uses_substance) ?= (RO:substance_used_by) (6759)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:has_basis_of_strength_substance) ?= (RO:basis_of_strength_substance_of) (6554)
# Auto resolve to keep left (1)
# (RO:has_focus) ?= (RO:focus_of) (6493)
# Auto resolve to keep left (1)
# (RO:has_measured_component) ?= (RO:measured_component_of) (6301)
# Auto resolve to keep left (1)
# (RO:has_imaged_location) ?= (RO:is_imaged_location_for) (6270)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:negatively_regulates) ?= (RO:negatively_regulated_by) (6260)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:positively_regulates) ?= (RO:positively_regulated_by) (6248)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:is_stage_of_disease) ?= (RO:disease_is_stage) (6084)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_precise_active_ingredient) ?= (RO:precise_active_ingredient_of) (5992)
# Auto resolve to keep left (1)
# (RO:has_modality_type) ?= (RO:is_modality_type_for) (5967)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:procedure_context_of) ?= (RO:has_procedure_context) (5765)
# Auto resolve to keep right (2)
# (RO:has_associated_procedure) ?= (RO:associated_procedure_of) (5748)
# Auto resolve to keep left (1)
# (RO:inheritance_type_of) ?= (RO:has_inheritance_type) (5652)
# Auto resolve to keep right (2)
# (RO:has_presentation_strength_numerator_value) ?= (RO:presentation_strength_numerator_value_of) (5431)
# Auto resolve to keep left (1)
# (RO:has_divisor) ?= (RO:divisor_of) (5405)
# Auto resolve to keep left (1)
# (RO:has_imaging_focus) ?= (RO:is_imaging_focus_of) (5385)
# Auto resolve to keep left (1)
# (RO:is_not_normal_cell_origin_of_disease) ?= (RO:disease_excludes_normal_cell_origin) (5272)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:nichd_parent_of) ?= (RO:has_nichd_parent) (5234)
# Auto resolve to keep right (2)
# (RO:presentation_strength_numerator_unit_of) ?= (RO:has_presentation_strength_numerator_unit) (4998)
# Auto resolve to keep right (2)
# (RO:is_associated_anatomy_of_gene_product) ?= (CHD:member_of) (4966)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (CHD:member_of) ?= (RO:gene_product_has_associated_anatomy) (4966)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:gene_mapped_to_disease) ?= (RO:disease_mapped_to_gene) (4859)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (SY:has_tradename) ?= (SY:tradename_of) (4843)
# Auto resolve to keep left (1)
# (RO:is_structural_domain_or_motif_of_gene_product) ?= (RO:gene_product_has_structural_domain_or_motif) (4810)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:course_of) ?= (RO:has_course) (4808)
# Auto resolve to keep right (2)
# (RO:has_presentation_strength_denominator_value) ?= (RO:presentation_strength_denominator_value_of) (4763)
# Auto resolve to keep left (1)
# (RO:presentation_strength_denominator_value_of) ?= (RO:presentation_strength_denominator_unit_of) (4763)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:presentation_strength_denominator_unit_of) ?= (RO:has_presentation_strength_denominator_unit) (4763)
# Auto resolve to keep right (2)
# (RO:clinical_course_of) ?= (RO:has_clinical_course) (4719)
# Auto resolve to keep right (2)
# (RO:is_biochemical_function_of_gene_product) ?= (RO:gene_product_has_biochemical_function) (4571)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:member_of) ?= (RO:has_member) (4495)
# Auto resolve to keep right (2)
# (RO:has_precise_ingredient) ?= (RO:precise_ingredient_of) (4183)
# Auto resolve to keep left (1)
# (RO:unit_of_presentation_of) ?= (RO:has_unit_of_presentation) (4130)
# Auto resolve to keep right (2)
# (RO:specimen_of) ?= (RO:has_specimen) (4115)
# Auto resolve to keep right (2)
# (RO:revision_status_of) ?= (RO:has_revision_status) (4088)
# Auto resolve to keep right (2)
# (RO:has_ctcae_5_parent) ?= (RO:ctcae_5_parent_of) (4048)
# Auto resolve to keep left (1)
# (RO:gene_in_chromosomal_location) ?= (RO:is_chromosomal_location_of_gene) (3813)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:temporally_followed_by) ?= (RO:temporally_follows) (3778)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:is_not_primary_anatomic_site_of_disease) ?= (RO:disease_excludes_primary_anatomic_site) (3729)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_lateral_anatomic_location) ?= (RO:is_lateral_anatomic_location_of) (3464)
# Auto resolve to keep left (1)
# (RO:has_lateral_location_presence) ?= (RO:is_presence_of_lateral_location) (3446)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:gene_found_in_organism) ?= (RO:organism_has_gene) (3417)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:access_instrument_of) ?= (RO:has_access_instrument) (3410)
# Auto resolve to keep right (2)
# (RO:structural_class_of) ?= (RO:has_structural_class) (3364)
# Auto resolve to keep right (2)
# (RO:has_specimen_source_topography) ?= (RO:specimen_source_topography_of) (3323)
# Auto resolve to keep left (1)
# (RO:has_aggregation_view) ?= (RO:is_aggregation_view_of) (3289)
# Auto resolve to keep left (1)
# (RO:access_device_used_by) ?= (RO:uses_access_device) (3228)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:replaced_by) ?= (RO:replaces) (3197)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:eo_anatomy_is_associated_with_eo_disease) ?= (RO:eo_disease_has_associated_eo_anatomy) (3128)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:approach_of) ?= (RO:has_approach) (3123)
# Auto resolve to keep right (2)
# (RO:has_location) ?= (RO:location_of) (2910)
# Auto resolve to keep left (1)
# (RO:has_tributary) ?= (RO:tributary_of) (2759)
# Auto resolve to keep left (1)
# (RO:has_timing_of) ?= (RO:is_timing_for) (2665)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:finding_informer_of) ?= (RO:has_finding_informer) (2584)
# Auto resolve to keep right (2)
# (RO:has_given_pharmaceutical_substance) ?= (RO:is_given_pharmaceutical_substance_for) (2392)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RQ:see) ?= (RQ:see_from) (2373)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:has_contraindicating_class) ?= (RO:contraindicating_class_of) (2235)
# Auto resolve to keep left (1)
# (RO:molecular_abnormality_involves_gene) ?= (RO:gene_involved_in_molecular_abnormality) (2197)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:gene_associated_with_disease) ?= (RO:disease_has_associated_gene) (2177)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:genetic_biomarker_related_to) ?= (RO:related_to_genetic_biomarker) (2170)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:included_in) ?= (RO:includes) (2160)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:is_mechanism_of_action_of_chemical_or_drug) ?= (RO:chemical_or_drug_has_mechanism_of_action) (2146)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_nerve_supply) ?= (RO:nerve_supply_of) (2133)
# Auto resolve to keep left (1)
# (RO:has_modification) ?= (RO:is_modification_of) (2121)
# Auto resolve to keep left (1)
# (RO:priority_of) ?= (RO:has_priority) (1982)
# Auto resolve to keep right (2)
# (RO:has_specimen_procedure) ?= (RO:specimen_procedure_of) (1954)
# Auto resolve to keep left (1)
# (RO:continuous_proximally_with) ?= (RO:continuous_distally_with) (1948)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:is_physiologic_effect_of_chemical_or_drug) ?= (RO:chemical_or_drug_has_physiologic_effect) (1947)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_pharmaceutical_route) ?= (RO:is_pharmaceutical_route_for) (1909)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:cdrh_parent_of) ?= (RO:has_cdrh_parent) (1885)
# Auto resolve to keep right (2)
# (RO:has_specimen_substance) ?= (RO:specimen_substance_of) (1879)
# Auto resolve to keep left (1)
# (RO:has_concentration_strength_denominator_value) ?= (RO:has_concentration_strength_numerator_value) (1859)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_concentration_strength_numerator_value) ?= (RO:concentration_strength_denominator_value_of) (1859)
# Auto resolve to keep left (1)
# (RO:concentration_strength_denominator_value_of) ?= (RO:concentration_strength_numerator_unit_of) (1859)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:concentration_strength_numerator_unit_of) ?= (RO:concentration_strength_denominator_unit_of) (1859)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:concentration_strength_denominator_unit_of) ?= (RO:concentration_strength_numerator_value_of) (1859)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:concentration_strength_numerator_value_of) ?= (RO:has_concentration_strength_numerator_unit) (1859)
# Auto resolve to keep right (2)
# (RO:has_concentration_strength_numerator_unit) ?= (RO:has_concentration_strength_denominator_unit) (1859)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RQ:consider) ?= (RQ:consider_from) (1830)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:eo_disease_maps_to_human_disease) ?= (RO:human_disease_maps_to_eo_disease) (1829)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_free_acid_or_base_form) ?= (RO:has_salt_form) (1824)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:disease_may_have_associated_disease) ?= (RO:may_be_associated_disease_of_disease) (1821)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:contraindicated_class_of) ?= (RO:has_contraindicated_class) (1791)
# Auto resolve to keep right (2)
# (RO:has_indirect_morphology) ?= (RO:indirect_morphology_of) (1764)
# Auto resolve to keep left (1)
# (RO:has_view_type) ?= (RO:is_view_type_for) (1668)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:gene_product_has_chemical_classification) ?= (RO:is_chemical_classification_of_gene_product) (1654)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:wound_has_communication_with) ?= (RO:has_communication_with_wound) (1590)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:gene_product_expressed_in_tissue) ?= (RO:tissue_is_expression_site_of_gene_product) (1562)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:surgical_approach_of) ?= (RO:has_surgical_approach) (1498)
# Auto resolve to keep right (2)
# (RO:realization_of) ?= (RO:has_realization) (1471)
# Auto resolve to keep right (2)
# (RO:is_molecular_abnormality_of_disease) ?= (RO:disease_has_molecular_abnormality) (1383)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:is_organism_source_of_gene_product) ?= (RO:gene_product_has_organism_source) (1305)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:gene_product_has_organism_source) ?= (RO:extent_of) (1305)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:extent_of) ?= (RO:has_extent) (1305)
# Auto resolve to keep right (2)
# (RO:may_be_diagnosed_by) ?= (RO:may_diagnose) (1252)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:is_grade_of_disease) ?= (RO:disease_is_grade) (1245)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:gene_product_sequence_variation_encoded_by_gene_mutant) ?= (RO:gene_mutant_encodes_gene_product_sequence_variation) (1231)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:is_not_normal_tissue_origin_of_disease) ?= (RO:disease_excludes_normal_tissue_origin) (1191)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:exhibited_by) ?= (RO:exhibits) (1185)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:may_be_abnormal_cell_of_disease) ?= (RO:disease_may_have_abnormal_cell) (1145)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:gene_involved_in_pathogenesis_of_disease) ?= (RO:pathogenesis_of_disease_involves_gene) (1100)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:has_modality_subtype) ?= (RO:is_modality_subtype_for) (1069)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:is_action_guidance_for) ?= (RO:has_action_guidance) (1021)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_procedure_device) ?= (RO:procedure_device_of) (1015)
# Auto resolve to keep left (1)
# (RO:has_presence_guidance) ?= (RO:is_presence_guidance_for) (999)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:is_physical_location_of_gene) ?= (RO:gene_has_physical_location) (989)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:onset_of) ?= (RO:has_onset) (988)
# Auto resolve to keep right (2)
# (RO:induces) ?= (RO:induced_by) (966)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:disease_has_associated_disease) ?= (RO:is_associated_disease_of) (963)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:role_played_by) ?= (RO:plays_role) (939)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RQ:has_alias) ?= (RQ:alias_of) (916)
# Auto resolve to keep left (1)
# (RO:contraindicating_mechanism_of_action_of) ?= (RO:has_contraindicating_mechanism_of_action) (895)
# Auto resolve to keep right (2)
# (RO:pharmacokinetics_of) ?= (RO:has_pharmacokinetics) (890)
# Auto resolve to keep right (2)
# (RO:contains) ?= (RO:contained_in) (882)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:bounds) ?= (RO:bounded_by) (873)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:has_procedure_morphology) ?= (RO:procedure_morphology_of) (845)
# Auto resolve to keep left (1)
# (RO:product_monograph_title_of) ?= (RO:has_product_monograph_title) (828)
# Auto resolve to keep right (2)
# (RO:efferent_to) ?= (RO:afferent_to) (823)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:receives_input_from) ?= (RO:sends_output_to) (811)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:target_anatomy_has_procedure) ?= (RO:procedure_has_target_anatomy) (791)
# Keep left (1), keep right (2), skip (3), exit (0):
# Invalid option:
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:lymphatic_drainage_of) ?= (RO:has_lymphatic_drainage) (764)
# Auto resolve to keep right (2)
# (RO:segmental_supply_of) ?= (RO:has_segmental_supply) (705)
# Auto resolve to keep right (2)
# (RO:has_associated_etiologic_finding) ?= (RO:associated_etiologic_finding_of) (698)
# Auto resolve to keep left (1)
# (RO:contraindicating_physiologic_effect_of) ?= (RO:has_contraindicating_physiologic_effect) (666)
# Auto resolve to keep right (2)
# (RO:is_target) ?= (RO:has_target) (661)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:energy_used_by) ?= (RO:uses_energy) (650)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:enzyme_metabolizes_chemical_or_drug) ?= (RO:chemical_or_drug_is_metabolized_by_enzyme) (636)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:arterial_supply_of) ?= (RO:has_arterial_supply) (632)
# Auto resolve to keep right (2)
# (RO:cytogenetic_abnormality_involves_chromosome) ?= (RO:chromosome_involved_in_cytogenetic_abnormality) (590)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RQ:replaced_by) ?= (RQ:replaces) (575)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:anterior_to) ?= (RO:posterior_to) (545)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:is_location_of_biological_process) ?= (RO:biological_process_has_associated_location) (542)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:severity_of) ?= (RO:has_severity) (529)
# Auto resolve to keep right (2)
# (RO:is_not_molecular_abnormality_of_disease) ?= (RO:disease_excludes_molecular_abnormality) (524)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:chemical_or_drug_affects_cell_type_or_tissue) ?= (RO:cell_type_or_tissue_affected_by_chemical_or_drug) (523)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:gene_product_malfunction_associated_with_disease) ?= (RO:associated_with_malfunction_of_gene_product) (509)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:complex_has_physical_part) ?= (RO:gene_product_is_physical_part_of) (505)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:receives_attachment_from) ?= (RO:attaches_to) (500)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:direct_right_of) ?= (RO:direct_left_of) (487)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:process_includes_biological_process) ?= (RO:biological_process_is_part_of_process) (484)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:is_not_cytogenetic_abnormality_of_disease) ?= (RO:disease_excludes_cytogenetic_abnormality) (480)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:excised_anatomy_has_procedure) ?= (RO:procedure_has_excised_anatomy) (476)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:superior_to) ?= (RO:inferior_to) (469)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:metabolic_site_of) ?= (RO:site_of_metabolism) (441)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:is_exam_for) ?= (RO:has_exam) (431)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_contraindicated_mechanism_of_action) ?= (RO:contraindicated_mechanism_of_action_of) (422)
# Auto resolve to keep left (1)
# (RO:gene_product_variant_of_gene_product) ?= (RO:gene_product_has_gene_product_variant) (415)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:scale_type_of) ?= (RO:has_scale_type) (398)
# Auto resolve to keep right (2)
# (RO:has_specimen_source_identity) ?= (RO:specimen_source_identity_of) (397)
# Auto resolve to keep left (1)
# (RN:mapped_from) ?= (RO:regimen_has_accepted_use_for_disease) (387)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:regimen_has_accepted_use_for_disease) ?= (RO:disease_has_accepted_treatment_with_regimen) (387)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:supported_concept_relationship_in) ?= (RO:has_supported_concept_relationship) (383)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_maneuver_type) ?= (RO:is_maneuver_type_for) (380)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:chemical_or_drug_affects_gene_product) ?= (RO:gene_product_affected_by_chemical_or_drug) (374)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:instrumentation_of) ?= (RO:has_instrumentation) (368)
# Auto resolve to keep right (2)
# (RO:is_object_guidance_for) ?= (RO:has_object_guidance) (354)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (SY:print_name_of) ?= (SY:has_print_name) (344)
# Auto resolve to keep right (2)
# (RO:is_approach_guidance_for) ?= (RO:has_approach_guidance) (340)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:biomarker_type_includes_gene_product) ?= (RO:gene_product_is_biomarker_type) (337)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:gene_product_is_biomarker_type) ?= (RO:dose_form_intended_site_of) (337)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:dose_form_intended_site_of) ?= (RO:has_dose_form_intended_site) (337)
# Auto resolve to keep right (2)
# (RO:has_quotient) ?= (RO:quotient_of) (335)
# Auto resolve to keep left (1)
# (RO:route_of_administration_of) ?= (RO:has_route_of_administration) (333)
# Auto resolve to keep right (2)
# (RO:part_anatomy_structure_of) ?= (RO:has_part_anatomy_structure) (323)
# Auto resolve to keep right (2)
# (RO:is_location_of_anatomic_structure) ?= (RO:anatomic_structure_has_location) (312)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:dose_form_administration_method_of) ?= (RO:has_dose_form_administration_method) (289)
# Auto resolve to keep right (2)
# (RO:disease_has_cytogenetic_abnormality) ?= (RO:dose_form_release_characteristic_of) (285)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:dose_form_release_characteristic_of) ?= (RO:is_cytogenetic_abnormality_of_disease) (285)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:is_cytogenetic_abnormality_of_disease) ?= (RO:adjustment_of) (285)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:adjustment_of) ?= (RO:has_adjustment) (285)
# Auto resolve to keep right (2)
# (RO:has_adjustment) ?= (RO:has_dose_form_release_characteristic) (285)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:subject_of_information_of) ?= (RO:has_subject_of_information) (283)
# Auto resolve to keep right (2)
# (RO:eo_disease_has_property_or_attribute) ?= (RO:is_property_or_attribute_of_eo_disease) (277)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:derives) ?= (RO:derives_from) (274)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:has_basic_dose_form) ?= (RO:basic_dose_form_of) (273)
# Auto resolve to keep left (1)
# (RO:has_specimen_source_morphology) ?= (RO:specimen_source_morphology_of) (271)
# Auto resolve to keep left (1)
# (RO:has_contraindicated_physiologic_effect) ?= (RO:contraindicated_physiologic_effect_of) (270)
# Auto resolve to keep left (1)
# (RO:supported_concept_property_in) ?= (RO:has_supported_concept_property) (260)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:gene_has_abnormality) ?= (RO:is_abnormality_of_gene) (259)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:dose_form_transformation_of) ?= (RO:has_dose_form_transformation) (254)
# Auto resolve to keep right (2)
# (RO:associated_genetic_condition) ?= (RO:associated_disease) (243)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:projects_from) ?= (RO:has_projection) (224)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:receives_projection) ?= (RO:projects_to) (223)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:origin_of) ?= (RO:has_origin) (221)
# Auto resolve to keep right (2)
# (RO:procedure_has_partially_excised_anatomy) ?= (RO:partially_excised_anatomy_has_procedure) (208)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:disease_has_metastatic_anatomic_site) ?= (RO:is_metastatic_anatomic_site_of_disease) (206)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:is_metastatic_anatomic_site_of_disease) ?= (RO:has_time_modifier) (206)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:has_time_modifier) ?= (RO:time_modifier_of) (206)
# Auto resolve to keep left (1)
# (RO:lateral_to) ?= (RO:medial_to) (204)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:inc_parent_of) ?= (RO:has_inc_parent) (201)
# Auto resolve to keep right (2)
# (RO:has_indirect_device) ?= (RO:indirect_device_of) (200)
# Auto resolve to keep left (1)
# (RO:developmental_stage_of) ?= (RO:has_developmental_stage) (193)
# Auto resolve to keep right (2)
# (RO:episodicity_of) ?= (RO:has_episodicity) (191)
# Auto resolve to keep right (2)
# (RO:distal_to) ?= (RO:proximal_to) (182)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:insertion_of) ?= (RO:allele_has_abnormality) (180)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:allele_has_abnormality) ?= (RO:has_insertion) (180)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:has_insertion) ?= (RO:abnormality_associated_with_allele) (180)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:chromosome_mapped_to_disease) ?= (RO:disease_mapped_to_chromosome) (179)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:disease_may_have_normal_cell_origin) ?= (RO:may_be_normal_cell_origin_of_disease) (175)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:property_type_of) ?= (RO:has_property_type) (166)
# Auto resolve to keep right (2)
# (RO:has_recipient_category) ?= (RO:inheres_in) (156)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:inheres_in) ?= (RO:has_inherent_attribute) (156)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:has_inherent_attribute) ?= (RO:recipient_category_of) (156)
# Auto resolve to keep left (1)
# (RO:has_count) ?= (RO:count_of) (148)
# Auto resolve to keep left (1)
# (RO:surrounds) ?= (RO:surrounded_by) (140)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:surrounded_by) ?= (RO:connected_to) (140)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:venous_drainage_of) ?= (RO:state_of_matter_of) (132)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:state_of_matter_of) ?= (RO:has_venous_drainage) (132)
# Auto resolve to keep right (2)
# (RO:has_venous_drainage) ?= (RO:has_state_of_matter) (132)
# Keep left (1), keep right (2), skip (3), exit (0):3
# (RO:process_initiates_biological_process) ?= (RO:biological_process_has_initiator_process) (129)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:allele_plays_altered_role_in_process) ?= (RO:process_altered_by_allele) (128)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:characterized_by) ?= (RO:characterizes) (127)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:manufactures) ?= (RO:manufactured_by) (117)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:chemical_or_drug_initiates_biological_process) ?= (RO:biological_process_has_initiator_chemical_or_drug) (113)
# Keep left (1), keep right (2), skip (3), exit (0):1
# (RO:receives_drainage_from) ?= (RO:drains_into) (107)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:special_category_includes_neoplasm) ?= (RO:neoplasm_has_special_category) (105)
# Keep left (1), keep right (2), skip (3), exit (0):2
# (RO:chromosomal_location_of_allele) ?= (RO:allele_in_chromosomal_location) (104)
# Keep left (1), keep right (2), skip (3), exit (0):2

# %%
with open('removed_rels.txt', 'w') as f:
  for (f_rel, f_rela, f_count) in removed_rels:
    f.write(f'{f_rel}, {f_rela}, {f_count}\n')

# %%
filtered_rels = set(kept_rels) - set(removed_rels)
filtered_rels = sorted(list(filtered_rels), key=lambda x: -x[2])
exit_early = False
new_count = 0
for (f_rel, f_rela, f_count) in filtered_rels:
  print(f'{f_rel}, {f_rela}, {f_count}')
  new_count += f_count
print(f'filtered rel count: {new_count}')
# Out:
# CHD, , 2125393
# CHD, isa, 1383066
# RO, has_inactive_ingredient, 1253624
# AQ, , 602217
# RO, has_finding_site, 355131
# RN, mapped_to, 354410
# RO, has_active_ingredient, 342188
# RO, has_method, 337561
# RN, , 321690
# RN, isa, 321396
# RQ, classifies, 316858
# RO, has_active_moiety, 284521
# RO, has_associated_morphology, 253171
# RO, has_component, 249916
# RO, has_ingredient, 238135
# RO, concept_in_subset, 199280
# RO, has_dose_form, 133035
# RO, has_procedure_site, 129560
# RO, has_system, 127876
# RO, has_manifestation, 113166
# RO, constitutes, 110875
# RN, tradename_of, 109579
# RO, has_class, 98438
# RO, has_fragments_for_synonyms, 95071
# RO, has_time_aspect, 88953
# RO, has_scale, 85824
# RO, has_property, 85545
# RO, has_causative_agent, 84622
# RN, part_of, 84035
# RO, has_direct_procedure_site, 82208
# RO, may_treat, 81544
# RO, interprets, 80351
# RO, answer_to, 79378
# RO, measures, 78947
# RO, analyzes, 72041
# RO, possibly_equivalent_to, 65964
# RO, mapped_to, 63108
# RQ, , 59292
# RO, has_physiologic_effect, 55461
# RO, has_contraindicated_drug, 51755
# RO, has_pathological_process, 51006
# RO, is_abnormal_cell_of_disease, 46877
# RO, has_product_component, 41393
# RN, member_of, 40441
# RO, has_mechanism_of_action, 40257
# RO, occurs_in, 38683
# RO, has_doseformgroup, 36868
# RO, process_involves_gene, 36159
# RO, is_associated_anatomic_site_of, 35182
# RO, has_mapping_qualifier, 34941
# RO, is_finding_of_disease, 34569
# RO, has_suffix, 33039
# RO, has_phenotype, 29871
# RO, has_direct_morphology, 29450
# RQ, has_allelic_variant, 28045
# RO, has_regional_part, 27627
# RO, has_indirect_procedure_site, 26964
# RO, has_intent, 25807
# RO, disease_has_primary_anatomic_site, 22837
# RO, has_direct_substance, 22706
# RO, has_interpretation, 22664
# RO, disease_excludes_finding, 22525
# RO, has_constitutional_part, 21420
# RO, has_multipart, 21044
# RO, biological_process_involves_gene_product, 20630
# CHD, part_of, 19395
# RO, has_challenge, 19300
# RO, is_normal_tissue_origin_of_disease, 18749
# RO, has_supersystem, 18469
# CHD, has_parent, 18113
# RO, is_normal_cell_origin_of_disease, 18084
# RO, gene_encodes_gene_product, 17928
# RO, has_direct_device, 17608
# RO, moved_to, 17336
# RO, is_not_abnormal_cell_of_disease, 17037
# RO, has_temporal_context, 16708
# RO, has_subject_relationship_context, 16447
# RO, may_be_finding_of_disease, 16164
# RN, was_a, 15587
# RO, has_entire_anatomy_structure, 14162
# RO, has_gene_product_element, 13414
# RO, pathway_has_gene_element, 13305
# RO, may_prevent, 12362
# RO, has_chemical_structure, 12320
# RO, has_associated_finding, 12137
# RO, has_branch, 12093
# RO, associated_with, 11736
# RO, has_count_of_base_of_active_ingredient, 11713
# RO, has_ingredients, 11649
# RO, chemotherapy_regimen_has_component, 11381
# RO, uses_device, 10983
# RO, has_finding_context, 10958
# RO, has_definitional_manifestation, 10882
# RO, has_part, 10610
# RO, may_be_cytogenetic_abnormality_of_disease, 10583
# SY, same_as, 10512
# RQ, mapped_to, 10191
# RO, has_access, 9495
# RO, has_evaluation, 9398
# RO, has_physical_part_of_anatomic_structure, 9336
# RO, has_disposition, 9176
# RO, has_finding_method, 9110
# RO, has_laterality, 8804
# RO, due_to, 8784
# RO, disease_may_have_molecular_abnormality, 8720
# RQ, use, 8213
# RO, uses, 7663
# RO, occurs_after, 7206
# RO, regulates, 7180
# RQ, clinically_similar, 6916
# RO, has_therapeutic_class, 6834
# RO, uses_substance, 6759
# RN, has_precise_ingredient, 6671
# RO, has_basis_of_strength_substance, 6554
# RO, has_focus, 6493
# RO, has_measured_component, 6301
# RO, has_imaged_location, 6270
# RO, negatively_regulates, 6260
# RO, positively_regulates, 6248
# RO, disease_is_stage, 6084
# RO, has_precise_active_ingredient, 5992
# RO, has_modality_type, 5967
# RO, has_procedure_context, 5765
# RO, has_associated_procedure, 5748
# RO, has_inheritance_type, 5652
# RO, has_presentation_strength_numerator_value, 5431
# RO, has_divisor, 5405
# RO, has_imaging_focus, 5385
# CHD, branch_of, 5327
# RN, quantified_form_of, 5307
# RO, disease_excludes_normal_cell_origin, 5272
# RO, has_nichd_parent, 5234
# RO, has_presentation_strength_numerator_unit, 4998
# RO, is_associated_anatomy_of_gene_product, 4966
# CHD, member_of, 4966
# RO, gene_mapped_to_disease, 4859
# SY, has_tradename, 4843
# RO, gene_product_has_structural_domain_or_motif, 4810
# RO, has_course, 4808
# RO, has_presentation_strength_denominator_value, 4763
# RO, has_presentation_strength_denominator_unit, 4763
# RO, related_to, 4720
# RO, has_clinical_course, 4719
# RO, gene_product_has_biochemical_function, 4571
# RO, has_member, 4495
# RO, has_precise_ingredient, 4183
# RO, has_unit_of_presentation, 4130
# SY, , 4128
# RO, has_specimen, 4115
# RO, has_revision_status, 4088
# RO, has_ctcae_5_parent, 4048
# RO, gene_in_chromosomal_location, 3813
# RO, temporally_follows, 3778
# RO, disease_excludes_primary_anatomic_site, 3729
# RN, conceptual_part_of, 3590
# RO, related_part, 3584
# RO, has_lateral_anatomic_location, 3464
# RO, has_lateral_location_presence, 3446
# RO, organism_has_gene, 3417
# RO, has_access_instrument, 3410
# RO, has_structural_class, 3364
# RO, has_specimen_source_topography, 3323
# RO, has_aggregation_view, 3289
# RO, uses_access_device, 3228
# RO, replaces, 3197
# RO, eo_disease_has_associated_eo_anatomy, 3128
# RO, has_approach, 3123
# RO, has_location, 2910
# RN, form_of, 2841
# RO, has_tributary, 2759
# RO, is_timing_for, 2665
# RO, has_finding_informer, 2584
# RO, continuous_with, 2512
# RO, has_given_pharmaceutical_substance, 2392
# RQ, see, 2373
# RN, contains, 2331
# RO, has_contraindicating_class, 2235
# RO, molecular_abnormality_involves_gene, 2197
# RO, gene_associated_with_disease, 2177
# RO, related_to_genetic_biomarker, 2170
# RO, includes, 2160
# RO, chemical_or_drug_has_mechanism_of_action, 2146
# RO, has_nerve_supply, 2133
# RO, has_modification, 2121
# RN, lab_number_of, 2006
# RO, has_priority, 1982
# RO, has_specimen_procedure, 1954
# RO, continuous_proximally_with, 1948
# RO, chemical_or_drug_has_physiologic_effect, 1947
# RO, has_pharmaceutical_route, 1909
# RO, has_cdrh_parent, 1885
# RO, has_specimen_substance, 1879
# RO, has_concentration_strength_numerator_unit, 1859
# RO, concentration_strength_numerator_unit_of, 1859
# RO, has_concentration_strength_numerator_value, 1859
# RQ, consider, 1830
# RO, human_disease_maps_to_eo_disease, 1829
# RO, has_salt_form, 1824
# RO, disease_may_have_associated_disease, 1821
# RO, has_contraindicated_class, 1791
# RO, has_indirect_morphology, 1764
# RO, has_view_type, 1668
# CHD, tributary_of, 1659
# RO, gene_product_has_chemical_classification, 1654
# RO, has_communication_with_wound, 1590
# RO, gene_product_expressed_in_tissue, 1562
# RO, has_surgical_approach, 1498
# RO, has_realization, 1471
# RO, disease_has_molecular_abnormality, 1383
# RO, has_extent, 1305
# RO, gene_product_has_organism_source, 1305
# RO, may_diagnose, 1252
# RO, disease_is_grade, 1245
# RO, gene_mutant_encodes_gene_product_sequence_variation, 1231
# RO, disease_excludes_normal_tissue_origin, 1191
# RO, exhibits, 1185
# RO, disease_may_have_abnormal_cell, 1145
# RO, gene_involved_in_pathogenesis_of_disease, 1100
# RO, has_modality_subtype, 1069
# RO, has_action_guidance, 1021
# RO, has_procedure_device, 1015
# RO, has_presence_guidance, 999
# RO, gene_has_physical_location, 989
# RO, has_onset, 988
# RO, induces, 966
# RO, disease_has_associated_disease, 963
# RO, plays_role, 939
# RQ, has_alias, 916
# RO, has_contraindicating_mechanism_of_action, 895
# RO, has_pharmacokinetics, 890
# RO, contains, 882
# RO, bounds, 873
# RO, has_procedure_morphology, 845
# RO, has_product_monograph_title, 828
# RO, efferent_to, 823
# RO, receives_input_from, 811
# RO, procedure_has_target_anatomy, 791
# RO, has_lymphatic_drainage, 764
# RO, has_segmental_supply, 705
# RO, has_associated_etiologic_finding, 698
# RO, articulates_with, 688
# RO, has_contraindicating_physiologic_effect, 666
# RO, has_target, 661
# RO, uses_energy, 650
# RO, enzyme_metabolizes_chemical_or_drug, 636
# RO, has_arterial_supply, 632
# RO, cytogenetic_abnormality_involves_chromosome, 590
# RQ, replaces, 575
# RO, anterior_to, 545
# RO, biological_process_has_associated_location, 542
# RO, has_severity, 529
# RO, disease_excludes_molecular_abnormality, 524
# RO, chemical_or_drug_affects_cell_type_or_tissue, 523
# RO, gene_product_malfunction_associated_with_disease, 509
# RO, complex_has_physical_part, 505
# RO, attaches_to, 500
# RO, direct_right_of, 487
# RO, process_includes_biological_process, 484
# RN, refers_to, 481
# RO, disease_excludes_cytogenetic_abnormality, 480
# RO, procedure_has_excised_anatomy, 476
# RO, superior_to, 469
# RO, site_of_metabolism, 441
# RO, has_exam, 431
# RO, has_contraindicated_mechanism_of_action, 422
# RO, gene_product_variant_of_gene_product, 415
# RO, has_scale_type, 398
# RO, has_specimen_source_identity, 397
# RO, disease_has_accepted_treatment_with_regimen, 387
# RN, mapped_from, 387
# RO, has_supported_concept_relationship, 383
# RO, has_maneuver_type, 380
# RO, chemical_or_drug_affects_gene_product, 374
# RO, has_instrumentation, 368
# RO, has_object_guidance, 354
# SY, has_print_name, 344
# RO, has_approach_guidance, 340
# RO, gene_product_is_biomarker_type, 337
# RO, has_dose_form_intended_site, 337
# RO, has_quotient, 335
# RO, has_route_of_administration, 333
# RO, has_part_anatomy_structure, 323
# RO, anatomic_structure_has_location, 312
# RO, has_dose_form_administration_method, 289
# RO, has_adjustment, 285
# RO, dose_form_release_characteristic_of, 285
# RO, has_dose_form_release_characteristic, 285
# RO, disease_has_cytogenetic_abnormality, 285
# RO, has_subject_of_information, 283
# RO, eo_disease_has_property_or_attribute, 277
# RO, derives, 274
# RO, has_basic_dose_form, 273
# RO, has_specimen_source_morphology, 271
# RO, has_contraindicated_physiologic_effect, 270
# RO, has_supported_concept_property, 260
# RO, gene_has_abnormality, 259
# RO, has_dose_form_transformation, 254
# RO, related_object, 252
# RO, associated_disease, 243
# RO, has_projection, 224
# RO, projects_to, 223
# RO, has_origin, 221
# RO, procedure_has_partially_excised_anatomy, 208
# RO, disease_has_metastatic_anatomic_site, 206
# RO, has_time_modifier, 206
# RO, medial_to, 204
# RO, lateral_to, 204
# RO, has_inc_parent, 201
# RO, has_indirect_device, 200
# RO, has_developmental_stage, 193
# RO, has_episodicity, 191
# RO, proximal_to, 182
# RO, distal_to, 182
# RO, has_insertion, 180
# RO, allele_has_abnormality, 180
# RO, insertion_of, 180
# RO, disease_mapped_to_chromosome, 179
# RO, disease_may_have_normal_cell_origin, 175
# RN, has_alternative, 168
# RO, has_property_type, 166
# RO, has_recipient_category, 156
# RO, has_inherent_attribute, 156
# RO, has_count, 148
# RO, surrounds, 140
# RO, connected_to, 140
# RO, has_state_of_matter, 132
# RO, has_venous_drainage, 132
# RO, process_initiates_biological_process, 129
# RO, allele_plays_altered_role_in_process, 128
# RO, characterizes, 127
# RN, version_of, 125
# RO, manufactures, 117
# RO, chemical_or_drug_initiates_biological_process, 113
# RO, drains_into, 107
# RO, neoplasm_has_special_category, 105
# RO, allele_in_chromosomal_location, 104
# filtered rel count: 12833115

# %%
# start with identity mapping
def left_merge(x, y):
  count_mapping[x] += count_mapping[y]
  del count_mapping[y]
  merge_mapping[y] = x
def right_merge(x, y):
  left_merge(y, x)

def new_merge(x, y, z):
  count_mapping[z] = 0
  merge_mapping[z] = z
  left_merge(z, x)
  left_merge(z, y)
  
def left_multi_merge(x, y_list):
  for y in y_list:
    left_merge(x, y)

# %%
rela_mapping = defaultdict(list)
for (r, ra, rc) in filtered_rels:
  if ra != '':
    rela_mapping[ra].append(r)
  
for ra, r_list in rela_mapping.items():
  if len(r_list) > 1:
    print(f'{ra}: {r_list}')
# Out:
# isa: ['CHD', 'RN']
# mapped_to: ['RN', 'RO', 'RQ']
# part_of: ['RN', 'CHD']
# member_of: ['RN', 'CHD']
# has_precise_ingredient: ['RN', 'RO']
# replaces: ['RO', 'RQ']
# contains: ['RN', 'RO']

# %%
count_mapping = {(r, ra): rc for (r, ra, rc) in filtered_rels}
merge_mapping = {(r, ra): (r, ra) for (r, ra, rc) in filtered_rels}
# merge (CHD, ''), ('RN', ''), ('RN', 'isa'), ('CHD', 'has_parent') to ('CHD', 'isa')
left_multi_merge(('CHD', 'isa'), [('CHD', ''), ('RN', ''), ('RN', 'isa'), ('CHD', 'has_parent')])

# merge ['RN', 'RO', 'RQ'], 'mapped_to' to single 'RO', mapped_to
left_multi_merge(('RO', 'mapped_to'), [('RN', 'mapped_to'), ('RQ', 'mapped_to')])

# merge part_of: ['RN', 'CHD']
left_merge(('RN', 'part_of'), ('CHD', 'part_of'))

# merge member_of: ['RN', 'CHD']
left_merge(('RN', 'member_of'), ('CHD', 'member_of'))

# merge has_precise_ingredient: ['RN', 'RO']
left_merge(('RO', 'has_precise_ingredient'), ('RN', 'has_precise_ingredient'))

# merge replaces: ['RO', 'RQ']
left_merge(('RO', 'replaces'), ('RQ', 'replaces'))

# merge contains: ['RN', 'RO']
left_merge(('RO', 'contains'), ('RN', 'contains'))

# %%
with open('rel_merge_mapping.txt', 'w') as f:
  for (r, ra), (mr, mra) in merge_mapping.items():
    f.write(f'{r}:{ra},{mr}:{mra}\n')

# %%
with open('rel_count_mapping.txt', 'w') as f:
  for (r, ra), rc in count_mapping.items():
    f.write(f'{r}:{ra},{rc}\n')

# %%
final_count = 0
for (r, ra), rc in sorted(count_mapping.items(), key=lambda x: -x[1]):
  print(f'{r}:{ra} - {rc}')
  final_count += rc
print(f'final filtered rel count: {final_count}')
print(f'final filtered rel type count: {len(count_mapping)}')
# Out:
# CHD:isa - 4169658
# RO:has_inactive_ingredient - 1253624
# AQ: - 602217
# RO:mapped_to - 427709
# RO:has_finding_site - 355131
# RO:has_active_ingredient - 342188
# RO:has_method - 337561
# RQ:classifies - 316858
# RO:has_active_moiety - 284521
# RO:has_associated_morphology - 253171
# RO:has_component - 249916
# RO:has_ingredient - 238135
# RO:concept_in_subset - 199280
# RO:has_dose_form - 133035
# RO:has_procedure_site - 129560
# RO:has_system - 127876
# RO:has_manifestation - 113166
# RO:constitutes - 110875
# RN:tradename_of - 109579
# RN:part_of - 103430
# RO:has_class - 98438
# RO:has_fragments_for_synonyms - 95071
# RO:has_time_aspect - 88953
# RO:has_scale - 85824
# RO:has_property - 85545
# RO:has_causative_agent - 84622
# RO:has_direct_procedure_site - 82208
# RO:may_treat - 81544
# RO:interprets - 80351
# RO:answer_to - 79378
# RO:measures - 78947
# RO:analyzes - 72041
# RO:possibly_equivalent_to - 65964
# RQ: - 59292
# RO:has_physiologic_effect - 55461
# RO:has_contraindicated_drug - 51755
# RO:has_pathological_process - 51006
# RO:is_abnormal_cell_of_disease - 46877
# RN:member_of - 45407
# RO:has_product_component - 41393
# RO:has_mechanism_of_action - 40257
# RO:occurs_in - 38683
# RO:has_doseformgroup - 36868
# RO:process_involves_gene - 36159
# RO:is_associated_anatomic_site_of - 35182
# RO:has_mapping_qualifier - 34941
# RO:is_finding_of_disease - 34569
# RO:has_suffix - 33039
# RO:has_phenotype - 29871
# RO:has_direct_morphology - 29450
# RQ:has_allelic_variant - 28045
# RO:has_regional_part - 27627
# RO:has_indirect_procedure_site - 26964
# RO:has_intent - 25807
# RO:disease_has_primary_anatomic_site - 22837
# RO:has_direct_substance - 22706
# RO:has_interpretation - 22664
# RO:disease_excludes_finding - 22525
# RO:has_constitutional_part - 21420
# RO:has_multipart - 21044
# RO:biological_process_involves_gene_product - 20630
# RO:has_challenge - 19300
# RO:is_normal_tissue_origin_of_disease - 18749
# RO:has_supersystem - 18469
# RO:is_normal_cell_origin_of_disease - 18084
# RO:gene_encodes_gene_product - 17928
# RO:has_direct_device - 17608
# RO:moved_to - 17336
# RO:is_not_abnormal_cell_of_disease - 17037
# RO:has_temporal_context - 16708
# RO:has_subject_relationship_context - 16447
# RO:may_be_finding_of_disease - 16164
# RN:was_a - 15587
# RO:has_entire_anatomy_structure - 14162
# RO:has_gene_product_element - 13414
# RO:pathway_has_gene_element - 13305
# RO:may_prevent - 12362
# RO:has_chemical_structure - 12320
# RO:has_associated_finding - 12137
# RO:has_branch - 12093
# RO:associated_with - 11736
# RO:has_count_of_base_of_active_ingredient - 11713
# RO:has_ingredients - 11649
# RO:chemotherapy_regimen_has_component - 11381
# RO:uses_device - 10983
# RO:has_finding_context - 10958
# RO:has_definitional_manifestation - 10882
# RO:has_precise_ingredient - 10854
# RO:has_part - 10610
# RO:may_be_cytogenetic_abnormality_of_disease - 10583
# SY:same_as - 10512
# RO:has_access - 9495
# RO:has_evaluation - 9398
# RO:has_physical_part_of_anatomic_structure - 9336
# RO:has_disposition - 9176
# RO:has_finding_method - 9110
# RO:has_laterality - 8804
# RO:due_to - 8784
# RO:disease_may_have_molecular_abnormality - 8720
# RQ:use - 8213
# RO:uses - 7663
# RO:occurs_after - 7206
# RO:regulates - 7180
# RQ:clinically_similar - 6916
# RO:has_therapeutic_class - 6834
# RO:uses_substance - 6759
# RO:has_basis_of_strength_substance - 6554
# RO:has_focus - 6493
# RO:has_measured_component - 6301
# RO:has_imaged_location - 6270
# RO:negatively_regulates - 6260
# RO:positively_regulates - 6248
# RO:disease_is_stage - 6084
# RO:has_precise_active_ingredient - 5992
# RO:has_modality_type - 5967
# RO:has_procedure_context - 5765
# RO:has_associated_procedure - 5748
# RO:has_inheritance_type - 5652
# RO:has_presentation_strength_numerator_value - 5431
# RO:has_divisor - 5405
# RO:has_imaging_focus - 5385
# CHD:branch_of - 5327
# RN:quantified_form_of - 5307
# RO:disease_excludes_normal_cell_origin - 5272
# RO:has_nichd_parent - 5234
# RO:has_presentation_strength_numerator_unit - 4998
# RO:is_associated_anatomy_of_gene_product - 4966
# RO:gene_mapped_to_disease - 4859
# SY:has_tradename - 4843
# RO:gene_product_has_structural_domain_or_motif - 4810
# RO:has_course - 4808
# RO:has_presentation_strength_denominator_value - 4763
# RO:has_presentation_strength_denominator_unit - 4763
# RO:related_to - 4720
# RO:has_clinical_course - 4719
# RO:gene_product_has_biochemical_function - 4571
# RO:has_member - 4495
# RO:has_unit_of_presentation - 4130
# SY: - 4128
# RO:has_specimen - 4115
# RO:has_revision_status - 4088
# RO:has_ctcae_5_parent - 4048
# RO:gene_in_chromosomal_location - 3813
# RO:temporally_follows - 3778
# RO:replaces - 3772
# RO:disease_excludes_primary_anatomic_site - 3729
# RN:conceptual_part_of - 3590
# RO:related_part - 3584
# RO:has_lateral_anatomic_location - 3464
# RO:has_lateral_location_presence - 3446
# RO:organism_has_gene - 3417
# RO:has_access_instrument - 3410
# RO:has_structural_class - 3364
# RO:has_specimen_source_topography - 3323
# RO:has_aggregation_view - 3289
# RO:uses_access_device - 3228
# RO:contains - 3213
# RO:eo_disease_has_associated_eo_anatomy - 3128
# RO:has_approach - 3123
# RO:has_location - 2910
# RN:form_of - 2841
# RO:has_tributary - 2759
# RO:is_timing_for - 2665
# RO:has_finding_informer - 2584
# RO:continuous_with - 2512
# RO:has_given_pharmaceutical_substance - 2392
# RQ:see - 2373
# RO:has_contraindicating_class - 2235
# RO:molecular_abnormality_involves_gene - 2197
# RO:gene_associated_with_disease - 2177
# RO:related_to_genetic_biomarker - 2170
# RO:includes - 2160
# RO:chemical_or_drug_has_mechanism_of_action - 2146
# RO:has_nerve_supply - 2133
# RO:has_modification - 2121
# RN:lab_number_of - 2006
# RO:has_priority - 1982
# RO:has_specimen_procedure - 1954
# RO:continuous_proximally_with - 1948
# RO:chemical_or_drug_has_physiologic_effect - 1947
# RO:has_pharmaceutical_route - 1909
# RO:has_cdrh_parent - 1885
# RO:has_specimen_substance - 1879
# RO:has_concentration_strength_numerator_unit - 1859
# RO:concentration_strength_numerator_unit_of - 1859
# RO:has_concentration_strength_numerator_value - 1859
# RQ:consider - 1830
# RO:human_disease_maps_to_eo_disease - 1829
# RO:has_salt_form - 1824
# RO:disease_may_have_associated_disease - 1821
# RO:has_contraindicated_class - 1791
# RO:has_indirect_morphology - 1764
# RO:has_view_type - 1668
# CHD:tributary_of - 1659
# RO:gene_product_has_chemical_classification - 1654
# RO:has_communication_with_wound - 1590
# RO:gene_product_expressed_in_tissue - 1562
# RO:has_surgical_approach - 1498
# RO:has_realization - 1471
# RO:disease_has_molecular_abnormality - 1383
# RO:has_extent - 1305
# RO:gene_product_has_organism_source - 1305
# RO:may_diagnose - 1252
# RO:disease_is_grade - 1245
# RO:gene_mutant_encodes_gene_product_sequence_variation - 1231
# RO:disease_excludes_normal_tissue_origin - 1191
# RO:exhibits - 1185
# RO:disease_may_have_abnormal_cell - 1145
# RO:gene_involved_in_pathogenesis_of_disease - 1100
# RO:has_modality_subtype - 1069
# RO:has_action_guidance - 1021
# RO:has_procedure_device - 1015
# RO:has_presence_guidance - 999
# RO:gene_has_physical_location - 989
# RO:has_onset - 988
# RO:induces - 966
# RO:disease_has_associated_disease - 963
# RO:plays_role - 939
# RQ:has_alias - 916
# RO:has_contraindicating_mechanism_of_action - 895
# RO:has_pharmacokinetics - 890
# RO:bounds - 873
# RO:has_procedure_morphology - 845
# RO:has_product_monograph_title - 828
# RO:efferent_to - 823
# RO:receives_input_from - 811
# RO:procedure_has_target_anatomy - 791
# RO:has_lymphatic_drainage - 764
# RO:has_segmental_supply - 705
# RO:has_associated_etiologic_finding - 698
# RO:articulates_with - 688
# RO:has_contraindicating_physiologic_effect - 666
# RO:has_target - 661
# RO:uses_energy - 650
# RO:enzyme_metabolizes_chemical_or_drug - 636
# RO:has_arterial_supply - 632
# RO:cytogenetic_abnormality_involves_chromosome - 590
# RO:anterior_to - 545
# RO:biological_process_has_associated_location - 542
# RO:has_severity - 529
# RO:disease_excludes_molecular_abnormality - 524
# RO:chemical_or_drug_affects_cell_type_or_tissue - 523
# RO:gene_product_malfunction_associated_with_disease - 509
# RO:complex_has_physical_part - 505
# RO:attaches_to - 500
# RO:direct_right_of - 487
# RO:process_includes_biological_process - 484
# RN:refers_to - 481
# RO:disease_excludes_cytogenetic_abnormality - 480
# RO:procedure_has_excised_anatomy - 476
# RO:superior_to - 469
# RO:site_of_metabolism - 441
# RO:has_exam - 431
# RO:has_contraindicated_mechanism_of_action - 422
# RO:gene_product_variant_of_gene_product - 415
# RO:has_scale_type - 398
# RO:has_specimen_source_identity - 397
# RO:disease_has_accepted_treatment_with_regimen - 387
# RN:mapped_from - 387
# RO:has_supported_concept_relationship - 383
# RO:has_maneuver_type - 380
# RO:chemical_or_drug_affects_gene_product - 374
# RO:has_instrumentation - 368
# RO:has_object_guidance - 354
# SY:has_print_name - 344
# RO:has_approach_guidance - 340
# RO:gene_product_is_biomarker_type - 337
# RO:has_dose_form_intended_site - 337
# RO:has_quotient - 335
# RO:has_route_of_administration - 333
# RO:has_part_anatomy_structure - 323
# RO:anatomic_structure_has_location - 312
# RO:has_dose_form_administration_method - 289
# RO:has_adjustment - 285
# RO:dose_form_release_characteristic_of - 285
# RO:has_dose_form_release_characteristic - 285
# RO:disease_has_cytogenetic_abnormality - 285
# RO:has_subject_of_information - 283
# RO:eo_disease_has_property_or_attribute - 277
# RO:derives - 274
# RO:has_basic_dose_form - 273
# RO:has_specimen_source_morphology - 271
# RO:has_contraindicated_physiologic_effect - 270
# RO:has_supported_concept_property - 260
# RO:gene_has_abnormality - 259
# RO:has_dose_form_transformation - 254
# RO:related_object - 252
# RO:associated_disease - 243
# RO:has_projection - 224
# RO:projects_to - 223
# RO:has_origin - 221
# RO:procedure_has_partially_excised_anatomy - 208
# RO:disease_has_metastatic_anatomic_site - 206
# RO:has_time_modifier - 206
# RO:medial_to - 204
# RO:lateral_to - 204
# RO:has_inc_parent - 201
# RO:has_indirect_device - 200
# RO:has_developmental_stage - 193
# RO:has_episodicity - 191
# RO:proximal_to - 182
# RO:distal_to - 182
# RO:has_insertion - 180
# RO:allele_has_abnormality - 180
# RO:insertion_of - 180
# RO:disease_mapped_to_chromosome - 179
# RO:disease_may_have_normal_cell_origin - 175
# RN:has_alternative - 168
# RO:has_property_type - 166
# RO:has_recipient_category - 156
# RO:has_inherent_attribute - 156
# RO:has_count - 148
# RO:surrounds - 140
# RO:connected_to - 140
# RO:has_state_of_matter - 132
# RO:has_venous_drainage - 132
# RO:process_initiates_biological_process - 129
# RO:allele_plays_altered_role_in_process - 128
# RO:characterizes - 127
# RN:version_of - 125
# RO:manufactures - 117
# RO:chemical_or_drug_initiates_biological_process - 113
# RO:drains_into - 107
# RO:neoplasm_has_special_category - 105
# RO:allele_in_chromosomal_location - 104
# final filtered rel count: 12833115
# final filtered rel type count: 325

# %%
# !ls
# Out:
# DataValidation.ipynb	 pyumls			removed_rels.txt
# ExploreRels.ipynb	 rel_count_mapping.txt
# ExploreRels-Stats.ipynb  rel_merge_mapping.txt
